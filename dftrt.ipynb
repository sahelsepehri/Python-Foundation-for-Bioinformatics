# %% [markdown]
# +--------------------------------+

# %% [markdown]
# <html>
# <div style="
# background:linear-gradient(135deg, #0F4C81, #1e7a2c);
# padding:35px;
# border-radius:15px;
# color:white;
# margin-bottom:35px;
# ">
#
# <h2 style="margin:0;">
# Differential Gene Expression Analysis of Lung Adenocarcinoma (LUAD)
# </h2>
#
# <p style="margin-top:12px;font-size:17px;">
# Bioinformatics & Computational Biology Project
# </p>
#
# <p style="margin-top:20px;font-size:14px;opacity:.9;">
# Sahel Sepehri • June 2026
# </p>
#
# </div>
# </html>

# %% [markdown]
# <style>
#
# .figure{
#     background:white;
#     padding:20px;
#     border-radius:15px;
#     box-shadow:0 3px 12px rgba(0,0,0,.08);
#     margin:30px 0;
# }
#
# .figure img{
#     width:80%;      /* اینجا اندازه عکس را عوض کن */
#     display:block;
#     margin:auto;
#     border-radius:12px;
# }
#
# .figure h3{
#     margin:10px 0 5px;
# }
#
# .figure p{
#     color:#555;
# }
#
# </style>

# %% [markdown]
# <html>
# <div class="figure">
#
# <img src="https://github.com/sahelsepehri/LUAD-Transcriptomics_Project/blob/main/Images/DisGeNET_table.png?raw=true">
#
# <h3>Figure 1. Volcano Plot</h3>
#
# <p>
# Differentially expressed genes identified using GEO2R.
# </p>
#
# </div>
# </html>
#
# https://github.com/sahelsepehri/LUAD-Transcriptomics_Project/blob/main/Images/DisGeNET_table.png?raw=true

# %% [markdown]
# <div style="
# background:#ffffff;
# border-left:6px solid #1e7a2c;
# padding:15px 20px;
# border-radius:10px;
# margin:40px 0 25px 0;
# box-shadow:0 2px 8px rgba(0,0,0,.08);
# ">
#
# <h2 style="margin:0;color:#0F4C81;">
# Volcano Plot
# </h2>
#
# <p style="margin-top:6px;color:#666;font-size:15px;">
# Differential expression analysis
# </p>
#
# </div>

# %% [markdown]
# <div style="
# border-bottom:3px solid #1e7a2c;
# margin:45px 0 25px 0;
# padding-bottom:8px;
# ">
#
# <h2 style="
# margin:0;
# color:#0F4C81;
# font-size:28px;
# ">
#
# GO Biological Process
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# background:#ffffff;
# border-left:6px solid #1e7a2c;
# padding:15px 20px;
# border-radius:10px;
# margin:40px 0 25px 0;
# box-shadow:0 2px 8px rgba(0,0,0,.08);
# ">
#
# <h2 style="margin:0;color:#0F4C81;">
# STRING Protein–Protein Interaction Network
# </h2>
#
# <p style="margin-top:6px;color:#666;font-size:15px;">
# Protein interaction analysis
# </p>
#
# </div>
